# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/d/d4/MercadoLibre_logo.PNG" align="center" width="400"/>

# %%
# %%javascript
# /** Below because this notebook is pretty large */
# var rto = 200;
# console.log('NB: Increase require timeout to ' + rto + ' seconds');
# window.requirejs.config({waitSeconds: rto});

# %%
SEMILLA = 99

# %%
CLASIFICADOR = 'LGBM'
N_ITERACIONES = 50

# %% [markdown]
# ## Importacion de Librerías y Configuración de Consola

# %%
import imblearn
from imblearn.pipeline import Pipeline

import time 
import os
import janitor
import pandas as pd
import numpy as np

from pathlib import Path

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
import skopt
from skopt.space import Real, Integer, Categorical
from skopt.utils import use_named_args
from skopt import gp_minimize, forest_minimize, dump

import joblib

from scipy import stats
# import feature_engine

import lightgbm as lgb

# %%
# Especificamos el directorio base, retrocediendo una carpeta
BASE = Path('..')
# Y, a partir de allí, definimos las carpetas que debieran existir
RAW = BASE/'raw'
NOTEBOOKS = BASE/'notebooks'
DATA = BASE/'data'
REFERENCIAS = BASE/'referencias'
PERFORMANCE = BASE/'performance'
MODELOS = BASE/'modelos'

# %%
# Creamos todos los directorios que definimos previamente, si no existieran aún.
path_list = [RAW, NOTEBOOKS, DATA, REFERENCIAS, PERFORMANCE, MODELOS]
for path_i in path_list:
    if not os.path.exists(path_i):
        os.makedirs(path_i)

# %%
#Tomo el tiempo al inicio de la ejecucion
start_time=time.time()

# %%
#Seteamos para que no utilice notacion cientifica
pd.options.display.float_format = '{:.9f}'.format
#Seteo para que el máximo de columnas que muestra al levantar una base sean 500
pd.set_option('display.max_columns',500)
#Estos códigos hacen que la visualización de la consola abarque toda la pantalla (sin los recortes a los costados). Tambien hacen que al mostrar dataframes podamos ver todas las columnas que tiene.
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# Codigo para poder imprimir multiples outputs en una misma línea
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# Definiremos el directorio en el que estamos trabajando. 
scripts=os.getcwd()  #Obtenemos la direccion actual
os.chdir('..') # Nos vamos una carpeta atrás
raiz=os.getcwd() # Esta direccion la guardaremos como "raiz" 
os.chdir(raiz+'\\raw') 
raw=os.getcwd()
os.chdir(raiz+'\\raw')
outputs=os.getcwd()

# %%
from datetime import date
today = date.today()
Today_Date = str(today)

# %% [markdown]
# # Importacion de Archivos

# %%
# Lee file de acciones argentinas
dict_acciones_arg = np.load(DATA/'mi_dict_acciones_arg.npy',allow_pickle='TRUE').item()

# %%
dict_acciones_arg['ggal'].tail(2)
# Out:
#            date   volume        high         low    merv_close     merv_open  \
# 4744 2021-02-02  1310376 0.797385621 0.774509804 324.750510621 324.031964869
# 4745 2021-02-03  1047763 0.793464062 0.772549000 325.866344975 324.750510621
#
#          merv_high        open       close      merv_low    ratio_ho  \
# 4744 330.802670547 0.784313725 0.779084947 324.031964869 1.016666667
# 4745 329.267769608 0.778104595 0.773529402 324.658752042 1.019739592
#
#         ratio_lo    ratio_co    ratio_hc    ratio_lc    ratio_hl  \
# 4744 0.987500000 0.993333308 1.023489959 0.994127542 1.029535865
# 4745 0.992860092 0.994120079 1.025771044 0.998732560 1.027072797
#
#       ratio_o_mean  ratio_c_mean  ratio_l_mean  ratio_h_mean  ratio_o_meanc  \
# 4744   0.582897957   0.579011956   0.575611733   0.592612923    0.607764042
# 4745   0.578283363   0.574883103   0.574154473   0.589698441    0.602952593
#
#       ratio_c_meanc  ratio_l_meanc  ratio_h_meanc  var_orig_high_vs_1  \
# 4744    0.603712267    0.600166992    0.617893443         0.022631994
# 4745    0.599407279    0.598647566    0.614854631        -0.004918020
#
#       var_orig_high_vs_2  var_orig_high_vs_5  var_orig_ratio_c_meanc_vs_1  \
# 4744         0.012868436         0.046191382                  0.000419601
# 4745         0.017602669         0.019128140                 -0.007130860
#
#       var_orig_ratio_c_meanc_vs_2  var_orig_ratio_c_meanc_vs_5  \
# 4744                  0.030250649                  0.031725370
# 4745                 -0.006714251                  0.002723273
#
#       var_orig_merv_close_vs_1  var_orig_merv_close_vs_2  \
# 4744               0.002217515               0.029626445
# 4745               0.003435974               0.005661108
#
#       var_orig_merv_close_vs_5  var_orig_merv_open_vs_1  \
# 4744               0.024204344              0.027348284
# 4745               0.004262662              0.002217515
#
#       var_orig_merv_open_vs_2  var_orig_merv_open_vs_5  var_orig_open_vs_1  \
# 4744             -0.001071915              0.064862610         0.033591745
# 4745              0.029626445              0.011073519        -0.007916641
#
#       var_orig_open_vs_2  var_orig_open_vs_5  var_orig_ratio_h_mean_vs_1  \
# 4744        -0.003735965         0.088549284                 0.022631994
# 4745         0.025409170         0.020247857                -0.004918020
#
#       var_orig_ratio_h_mean_vs_2  var_orig_ratio_h_mean_vs_5  \
# 4744                 0.012868436                 0.046191382
# 4745                 0.017602669                 0.019128140
#
#       var_orig_ratio_hl_vs_1  var_orig_ratio_hl_vs_2  var_orig_ratio_hl_vs_5  \
# 4744             0.001920447            -0.016620113            -0.026746583
# 4745            -0.002392406            -0.000476553            -0.014900999
#
#       var_orig_ratio_l_meanc_vs_1  var_orig_ratio_l_meanc_vs_2  \
# 4744                  0.020671848                  0.029986935
# 4745                 -0.002531671                  0.018087842
#
#       var_orig_ratio_l_meanc_vs_5  var_orig_ratio_co_vs_1  \
# 4744                  0.074942418            -0.032094049
# 4745                  0.034543878             0.000792052
#
#       var_orig_ratio_co_vs_2  var_orig_ratio_co_vs_5  var_orig_merv_low_vs_1  \
# 4744             0.034114063            -0.052201507             0.027348284
# 4745            -0.031327417            -0.017176791             0.001934337
#
#       var_orig_merv_low_vs_2  var_orig_merv_low_vs_5  \
# 4744             0.028505181             0.064862610
# 4745             0.029335523             0.028670646
#
#       var_orig_ratio_o_mean_vs_1  var_orig_ratio_o_mean_vs_2  \
# 4744                 0.033591745                -0.003735965
# 4745                -0.007916641                 0.025409170
#
#       var_orig_ratio_o_mean_vs_5  var_orig_ratio_l_mean_vs_1  \
# 4744                 0.088549284                 0.020671848
# 4745                 0.020247857                -0.002531671
#
#       var_orig_ratio_l_mean_vs_2  var_orig_ratio_l_mean_vs_5  \
# 4744                 0.029986935                 0.074942418
# 4745                 0.018087842                 0.034543878
#
#       var_orig_ratio_o_meanc_vs_1  var_orig_ratio_o_meanc_vs_2  \
# 4744                  0.033591745                 -0.003735965
# 4745                 -0.007916641                  0.025409170
#
#       var_orig_ratio_o_meanc_vs_5  var_orig_ratio_ho_vs_1  \
# 4744                  0.088549284            -0.010603559
# 4745                  0.020247857             0.003022549
#
#       var_orig_ratio_ho_vs_2  var_orig_ratio_ho_vs_5  var_orig_volume_vs_1  \
# 4744             0.016666667            -0.038912250           0.497820782
# 4745            -0.007613059            -0.001097494          -0.200410417
#
#       var_orig_volume_vs_2  var_orig_volume_vs_5  var_orig_low_vs_1  \
# 4744          -0.155156451           0.126626584        0.020671848
# 4745           0.197641895          -0.004807071       -0.002531671
#
#       var_orig_low_vs_2  var_orig_low_vs_5  var_orig_merv_high_vs_1  \
# 4744        0.029986935        0.074942418              0.016856015
# 4745        0.018087842        0.034543878             -0.004639929
#
#       var_orig_merv_high_vs_2  var_orig_merv_high_vs_5  \
# 4744              0.012257595              0.041437483
# 4745              0.012137876              0.009731023
#
#       var_orig_ratio_lc_vs_1  var_orig_ratio_lc_vs_2  var_orig_ratio_lc_vs_5  \
# 4744             0.020243753            -0.000255971             0.041888131
# 4745             0.004632220             0.024969747             0.031734184
#
#       var_orig_close_vs_1  var_orig_close_vs_2  var_orig_close_vs_5  \
# 4744          0.000419601          0.030250649          0.031725370
# 4745         -0.007130860         -0.006714251          0.002723273
#
#       var_orig_ratio_lo_vs_1  var_orig_ratio_lo_vs_2  var_orig_ratio_lo_vs_5  \
# 4744            -0.012500000             0.033849360            -0.012500000
# 4745             0.005427941            -0.007139908             0.014012302
#
#       var_orig_ratio_c_mean_vs_1  var_orig_ratio_c_mean_vs_2  \
# 4744                 0.000419601                 0.030250649
# 4745                -0.007130860                -0.006714251
#
#       var_orig_ratio_c_mean_vs_5  var_orig_ratio_h_meanc_vs_1  \
# 4744                 0.031725370                  0.022631994
# 4745                 0.002723273                 -0.004918020
#
#       var_orig_ratio_h_meanc_vs_2  var_orig_ratio_h_meanc_vs_5  \
# 4744                  0.012868436                  0.046191382
# 4745                  0.017602669                  0.019128140
#
#       var_orig_ratio_hc_vs_1  var_orig_ratio_hc_vs_2  var_orig_ratio_hc_vs_5  \
# 4744             0.022203077            -0.016871829             0.014021184
# 4745             0.002228732             0.024481294             0.016360314
#
#       var_means_ratio_hc_m5d_m10d  var_means_ratio_hc_m5d_m12d  \
# 4744                 -0.001728102                 -0.002790788
# 4745                 -0.000184069                 -0.000005017
#
#       var_means_ratio_hc_m5d_m26d  var_means_ratio_hc_m5d_m120d  \
# 4744                 -0.001069599                  -0.006630978
# 4745                  0.001304594                  -0.003516037
#
#       var_means_ratio_hc_m5d_m252d  var_means_ratio_hc_m10d_m12d  \
# 4744                  -0.010508640                  -0.001064526
# 4745                  -0.007323186                   0.000179086
#
#       var_means_ratio_hc_m10d_m26d  var_means_ratio_hc_m10d_m120d  \
# 4744                   0.000659642                   -0.004911363
# 4745                   0.001488938                   -0.003332580
#
#       var_means_ratio_hc_m10d_m252d  var_means_ratio_hc_m12d_m26d  \
# 4744                   -0.008795739                   0.001726006
# 4745                   -0.007140431                   0.001309618
#
#       var_means_ratio_hc_m12d_m120d  var_means_ratio_hc_m12d_m252d  \
# 4744                   -0.003850937                   -0.007739451
# 4745                   -0.003511037                   -0.007318206
#
# 4745               0.003435974               0.005661108
#
#       var_orig_merv_close_vs_5  var_orig_merv_open_vs_1  \
# 2040               0.048225536              0.002931579
# 2041               0.049482501              0.023645637
# 2042               0.016382600              0.001294484
# 2043               0.026950865             -0.013246179
# 2044              -0.002520375              0.006637121
# ...                        ...                      ...
# 4741               0.034489625              0.007624020
# 4742               0.015111103              0.002277572
# 4743               0.064862610             -0.027663646
# 4744               0.024204344              0.027348284
# 4745               0.004262662              0.002217515
#
#       var_orig_merv_open_vs_2  var_orig_merv_open_vs_5  var_orig_open_vs_1  \
# 2040              0.005880397              0.033029294         0.006928400
# 2041              0.026646536              0.057223623         0.000000000
# 2042              0.024970730              0.048365668        -0.005154639
# 2043             -0.011968842              0.017341182        -0.015812039
# 2044             -0.006696975              0.021091187         0.014018678
# ...                       ...                      ...                 ...
# 4741              0.063582890              0.005250562        -0.001316830
# 4742              0.009918956              0.043955543         0.033606763
# 4743             -0.025449079              0.015111103        -0.036114559
# 4744             -0.001071915              0.064862610         0.033591745
# 4745              0.029626445              0.011073519        -0.007916641
#
#       var_orig_open_vs_2  var_orig_open_vs_5  var_orig_ratio_h_mean_vs_1  \
# 2040         0.013953474         0.057904771                 0.006864982
# 2041         0.006928400         0.065859039                 0.031818151
# 2042        -0.005154639         0.055525034                -0.035832661
# 2043        -0.020885173        -0.007223119                 0.002583979
# 2044        -0.002015025        -0.000280480                -0.013636350
# ...                  ...                 ...                         ...
# 4741         0.057105424         0.006085121                 0.004064230
# 4742         0.032245679         0.077296154                 0.007060123
# 4743        -0.003721489         0.038390079                -0.009547480
# 4744        -0.003735965         0.088549284                 0.022631994
# 4745         0.025409170         0.020247857                -0.004918020
#
#       var_orig_ratio_h_mean_vs_2  var_orig_ratio_h_mean_vs_5  \
# 2040                 0.013824871                 0.062427740
# 2041                 0.038901564                 0.088518863
# 2042                -0.005154639                 0.065208740
# 2043                -0.033341272                 0.011205169
# 2044                -0.011087607                -0.009431222
# ...                          ...                         ...
# 4741                 0.025658306                 0.022648001
# 4742                 0.011153047                 0.060550590
# 4743                -0.002554763                 0.059575048
# 4744                 0.012868436                 0.046191382
# 4745                 0.017602669                 0.019128140
#
#       var_orig_ratio_hl_vs_1  var_orig_ratio_hl_vs_2  var_orig_ratio_hl_vs_5  \
# 2040            -0.002457888            -0.004949757            -0.001258540
# 2041             0.022351939             0.019839112             0.021259682
# 2042            -0.008086692             0.014084493             0.032863817
# 2043             0.004717089            -0.003407749             0.013824871
# 2044            -0.013636350            -0.008983585             0.002504264
# ...                      ...                     ...                     ...
# 4741            -0.015584157            -0.029748328            -0.017103819
# 4742             0.020047077             0.004150504             0.021621517
# 4743            -0.018505022             0.001171084            -0.006450933
# 4744             0.001920447            -0.016620113            -0.026746583
# 4745            -0.002392406            -0.000476553            -0.014900999
#
#       var_orig_ratio_l_meanc_vs_1  var_orig_ratio_l_meanc_vs_2  \
# 2040                  0.009345841                  0.018868020
# 2041                  0.009259250                  0.018691627
# 2042                 -0.027972171                 -0.018971922
# 2043                 -0.002123095                 -0.030035878
# 2044                  0.000000000                 -0.002123095
# ...                           ...                          ...
# 4741                  0.019959437                  0.057105424
# 4742                 -0.012731720                  0.006973599
# 4743                  0.009126427                 -0.003721489
# 4744                  0.020671848                  0.029986935
# 4745                 -0.002531671                  0.018087842
#
#       var_orig_ratio_l_meanc_vs_5  var_orig_ratio_co_vs_1  \
# 2040                  0.063766533             0.000000023
# 2041                  0.065859039             0.027523000
# 2042                  0.031315768            -0.040178663
# 2043                 -0.002583979             0.037644095
# 2044                 -0.011905671            -0.036340373
# ...                           ...                     ...
# 4741                  0.040443559             0.004609191
# 4742                  0.038105181            -0.054708038
# 4743                  0.066454676             0.068403456
# 4744                  0.074942418            -0.032094049
# 4745                  0.034543878             0.000792052
#
#       var_orig_ratio_co_vs_2  var_orig_ratio_co_vs_5  var_orig_merv_low_vs_1  \
# 2040             0.000000047             0.014851391             0.005255392
# 2041             0.027523024             0.017546893             0.023645637
# 2042            -0.013761500            -0.013761660            -0.020834996
# 2043            -0.004047058             0.023364603            -0.003989462
# 2044            -0.000064279            -0.013824872             0.001170701
# ...                      ...                     ...                     ...
# 4741            -0.030424563             0.045366507             0.012598433
# 4742            -0.050351007            -0.031791689            -0.014189700
# 4743             0.009953199             0.041806161             0.001126100
# 4744             0.034114063            -0.052201507             0.027348284
# 4745            -0.031327417            -0.017176791             0.001934337
#
#       var_orig_merv_low_vs_2  var_orig_merv_low_vs_5  \
# 2040             0.010566314             0.033621242
# 2041             0.029025296             0.057223623
# 2042             0.002317985             0.025195874
# 2043            -0.024741337             0.008867830
# 2044            -0.002823432             0.004740709
# ...                      ...                     ...
# 4741             0.050252545             0.032722126
# 4742            -0.001770035             0.020415001
# 4743            -0.013079578             0.038305332
# 4744             0.028505181             0.064862610
# 4745             0.029335523             0.028670646
#
#       var_orig_ratio_o_mean_vs_1  var_orig_ratio_o_mean_vs_2  \
# 2040                 0.006928400                 0.013953474
# 2041                 0.000000000                 0.006928400
# 2042                -0.005154639                -0.005154639
# 2043                -0.015812039                -0.020885173
# 2044                 0.014018678                -0.002015025
# ...                          ...                         ...
# 4741                -0.001316830                 0.057105424
# 4742                 0.033606763                 0.032245679
# 4743                -0.036114559                -0.003721489
# 4744                 0.033591745                -0.003735965
# 4745                -0.007916641                 0.025409170
#
#       var_orig_ratio_o_mean_vs_5  var_orig_ratio_l_mean_vs_1  \
# 2040                 0.057904771                 0.009345841
# 2041                 0.065859039                 0.009259250
# 2042                 0.055525034                -0.027972171
# 2043                -0.007223119                -0.002123095
# 2044                -0.000280480                 0.000000000
# ...                          ...                         ...
# 4741                 0.006085121                 0.019959437
# 4742                 0.077296154                -0.012731720
# 4743                 0.038390079                 0.009126427
# 4744                 0.088549284                 0.020671848
# 4745                 0.020247857                -0.002531671
#
#       var_orig_ratio_l_mean_vs_2  var_orig_ratio_l_mean_vs_5  \
# 2040                 0.018868020                 0.063766533
# 2041                 0.018691627                 0.065859039
# 2042                -0.018971922                 0.031315768
# 2043                -0.030035878                -0.002583979
# 2044                -0.002123095                -0.011905671
# ...                          ...                         ...
# 4741                 0.057105424                 0.040443559
# 4742                 0.006973599                 0.038105181
# 4743                -0.003721489                 0.066454676
# 4744                 0.029986935                 0.074942418
# 4745                 0.018087842                 0.034543878
#
#       var_orig_ratio_o_meanc_vs_1  var_orig_ratio_o_meanc_vs_2  \
# 2040                  0.006928400                  0.013953474
# 2041                  0.000000000                  0.006928400
# 2042                 -0.005154639                 -0.005154639
# 2043                 -0.015812039                 -0.020885173
# 2044                  0.014018678                 -0.002015025
# ...                           ...                          ...
# 4741                 -0.001316830                  0.057105424
# 4742                  0.033606763                  0.032245679
# 4743                 -0.036114559                 -0.003721489
# 4744                  0.033591745                 -0.003735965
# 4745                 -0.007916641                  0.025409170
#
#       var_orig_ratio_o_meanc_vs_5  var_orig_ratio_ho_vs_1  \
# 2040                  0.057904771            -0.000062981
# 2041                  0.065859039             0.031818151
# 2042                  0.055525034            -0.030836975
# 2043                 -0.007223119             0.018691570
# 2044                 -0.000280480            -0.027272701
# ...                           ...                     ...
# 4741                  0.006085121             0.005388155
# 4742                  0.077296154            -0.025683501
# 4743                  0.038390079             0.027562486
# 4744                  0.088549284            -0.010603559
# 4745                  0.020247857             0.003022549
#
#       var_orig_ratio_ho_vs_2  var_orig_ratio_ho_vs_5  var_orig_volume_vs_1  \
# 2040            -0.000126834             0.004275403                   inf
# 2041             0.031753165             0.021259682           0.766958407
# 2042             0.000000000             0.009174303           0.231936031
# 2043            -0.012721797             0.018562366          -0.142293006
# 2044            -0.009090900            -0.009153309          -0.535049914
# ...                      ...                     ...                   ...
# 4741            -0.029748328             0.016462702          -0.232430112
# 4742            -0.020433733            -0.015544067           0.919313564
# 4743             0.001171084             0.020401745          -0.435951511
# 4744             0.016666667            -0.038912250           0.497820782
# 4745            -0.007613059            -0.001097494          -0.200410417
#
#       var_orig_volume_vs_2  var_orig_volume_vs_5  var_orig_low_vs_1  \
# 2040           0.412978543           0.030992810        0.009345841
# 2041                   inf           1.486557416        0.009259250
# 2042           1.176779727                   inf       -0.027972171
# 2043           0.056640150           1.638086323       -0.002123095
# 2044          -0.601209059                   inf        0.000000000
# ...                    ...                   ...                ...
# 4741          -0.305203263          -0.579546850        0.019959437
# 4742           0.473207298           0.052067231       -0.012731720
# 4743           0.082585916          -0.092553139        0.009126427
# 4744          -0.155156451           0.126626584        0.020671848
# 4745           0.197641895          -0.004807071       -0.002531671
#
#       var_orig_low_vs_2  var_orig_low_vs_5  var_orig_merv_high_vs_1  \
# 2040        0.018868020        0.063766533              0.013867758
# 2041        0.018691627        0.065859039              0.007427990
# 2042       -0.018971922        0.031315768             -0.009420437
# 2043       -0.030035878       -0.002583979             -0.000860882
# 2044       -0.002123095       -0.011905671             -0.006130936
# ...                 ...                ...                      ...
# 4741        0.057105424        0.040443559              0.003467665
# 4742        0.006973599        0.038105181             -0.001309180
# 4743       -0.003721489        0.066454676             -0.004522194
# 4744        0.029986935        0.074942418              0.016856015
# 4745        0.018087842        0.034543878             -0.004639929
#
#       var_orig_merv_high_vs_2  var_orig_merv_high_vs_5  \
# 2040              0.028125554              0.050246907
# 2041              0.021398757              0.051157139
# 4744                 0.031725370                  0.022631994
# 4745                 0.002723273                 -0.004918020
#
#       var_orig_ratio_h_meanc_vs_2  var_orig_ratio_h_meanc_vs_5  \
# 2040                  0.013824871                  0.062427740
# 2041                  0.038901564                  0.088518863
# 2042                 -0.005154639                  0.065208740
# 2043                 -0.033341272                  0.011205169
# 2044                 -0.011087607                 -0.009431222
# ...                           ...                          ...
# 4741                  0.025658306                  0.022648001
# 4742                  0.011153047                  0.060550590
# 4743                 -0.002554763                  0.059575048
# 4744                  0.012868436                  0.046191382
# 4745                  0.017602669                  0.019128140
#
#       var_orig_ratio_hc_vs_1  var_orig_ratio_hc_vs_2  var_orig_ratio_hc_vs_5  \
# 2040            -0.000063005            -0.000126880            -0.010421218
# 2041             0.004180101             0.004116834             0.003648764
# 2042             0.009732736             0.013953522             0.023256004
# 2043            -0.018264957            -0.008709989            -0.004692596
# 2044             0.009409622            -0.009027202             0.004737052
# ...                      ...                     ...                     ...
# 4741             0.000775390             0.000697455            -0.027649447
# 4742             0.030704310             0.031503507             0.016781121
# 4743            -0.038226168            -0.008695566            -0.020545489
# 4744             0.022203077            -0.016871829             0.014021184
# 4745             0.002228732             0.024481294             0.016360314
#
#       var_means_ratio_hc_m5d_m10d  var_means_ratio_hc_m5d_m12d  \
# 2040                  0.000296576                 -0.000447137
# 2041                 -0.000301162                  0.001109249
# 2042                  0.002000183                  0.003796019
# 2043                  0.002061142                  0.002479223
# 2044                  0.001617527                  0.002266517
# ...                           ...                          ...
# 4741                 -0.004223340                 -0.003505105
# 4742                 -0.002912390                 -0.002068585
# 4743                 -0.005176693                 -0.005281734
# 4744                 -0.001728102                 -0.002790788
# 4745                 -0.000184069                 -0.000005017
#
#       var_means_ratio_hc_m5d_m26d  var_means_ratio_hc_m5d_m120d  \
# 2040                 -0.001902745                  -0.004416376
# 2041                 -0.001328423                  -0.003735009
# 2042                  0.002390622                   0.000864050
# 2043                  0.001467824                  -0.000109566
# 2044                  0.003041707                   0.000719708
# ...                           ...                           ...
# 4741                 -0.003820514                  -0.009832505
# 4742                 -0.000263381                  -0.006600790
# 4743                 -0.004072931                  -0.009735595
# 4744                 -0.001069599                  -0.006630978
# 4745                  0.001304594                  -0.003516037
#
#       var_means_ratio_hc_m5d_m252d  var_means_ratio_hc_m10d_m12d  \
# 2040                  -0.025400220                  -0.000743493
# 2041                  -0.024737572                   0.001410837
# 2042                  -0.020182609                   0.001792251
# 2043                  -0.021116104                   0.000417221
# 2044                  -0.020239508                   0.000647942
# ...                            ...                           ...
# 4741                  -0.012499951                   0.000721281
# 4742                  -0.009257279                   0.000846270
# 4743                  -0.013191108                  -0.000105588
# 4744                  -0.010508640                  -0.001064526
# 4745                  -0.007323186                   0.000179086
#
#       var_means_ratio_hc_m10d_m26d  var_means_ratio_hc_m10d_m120d  \
# 2040                  -0.002198670                   -0.004711555
# 2041                  -0.001027570                   -0.003434881
# 2042                   0.000389660                   -0.001133865
# 2043                  -0.000592097                   -0.002166243
# 2044                   0.001421880                   -0.000896369
# ...                            ...                            ...
# 4741                   0.000404535                   -0.005632955
# 4742                   0.002656747                   -0.003699173
# 4743                   0.001109505                   -0.004582625
# 4744                   0.000659642                   -0.004911363
# 4745                   0.001488938                   -0.003332580
#
#       var_means_ratio_hc_m10d_m252d  var_means_ratio_hc_m12d_m26d  \
# 2040                   -0.025689177                  -0.001456259
# 2041                   -0.024443771                  -0.002434971
# 2042                   -0.022138511                  -0.001400082
# 2043                   -0.023129572                  -0.001008898
# 2044                   -0.021821738                   0.000773437
# ...                             ...                           ...
# 4741                   -0.008311714                  -0.000316518
# 4742                   -0.006363421                   0.001808947
# 4743                   -0.008056120                   0.001215221
# 4744                   -0.008795739                   0.001726006
# 4745                   -0.007140431                   0.001309618
#
#       var_means_ratio_hc_m12d_m120d  var_means_ratio_hc_m12d_m252d  \
# 2040                   -0.003971014                   -0.024964245
# 2041                   -0.004838891                   -0.025818183
# 2042                   -0.002920881                   -0.023887949
# 2043                   -0.002582387                   -0.023536973
# 2044                   -0.001543311                   -0.022455130
# ...                             ...                            ...
# 4741                   -0.006349656                   -0.009026484
# 4742                   -0.004541599                   -0.007203595
# 4743                   -0.004477510                   -0.007951372
# 4744                   -0.003850937                   -0.007739451
# 4745                   -0.003511037                   -0.007318206
#
#       var_means_ratio_hc_m26d_m120d  var_means_ratio_hc_m26d_m252d  \
# 2040                   -0.002518423                   -0.023542270
# 2041                   -0.002409788                   -0.023440288
# 2042                   -0.001522931                   -0.022519396
# 2043                   -0.001575078                   -0.022550827
# 2044                   -0.002314958                   -0.023210615
# ...                             ...                            ...
# 4741                   -0.006035048                   -0.008712724
# 4742                   -0.006339079                   -0.008996267
# 4743                   -0.005685822                   -0.009155467
# 4744                   -0.005567333                   -0.009449148
# 4745                   -0.004814350                   -0.008616540
#
#       var_means_ratio_hc_m120d_m252d  vd_1d  vd_5d  vd_10d  vd_22d
# 2040                    -0.021076927      1      1       1       1
# 2041                    -0.021081302      0      0       0       0
# 2042                    -0.021028489      1      1       1       1
# 2043                    -0.021008839      0      0       0       0
# 2044                    -0.020944142      0      0       0       0
# ...                              ...    ...    ...     ...     ...
# 4741                    -0.002693934      0      0       0       0
# 4742                    -0.002674140      1      0       0       0
# 4743                    -0.003489486      0      0       0       0
# 4744                    -0.003903547      0      0       0       0
# 4745                    -0.003820583      0      0       0       0
#
# [2706 rows x 112 columns]

# %%
# Split temporal entre train y test
df_train = ggal[(ggal['date']>='2010-01-01')&(ggal['date']<'2018-01-01')].set_index(['date'])
df_test  = ggal[ggal['date']>'2018-01-01'].set_index(['date'])

# Separamos la X (atributos) y las múltiples y 
X_train, X_test = df_train.drop(columns=list_vds) , df_test.drop(columns=list_vds)

y_train_dict = {}
y_test_dict = {}
# en el dictionary guardaremos los distintos dataframes, en cada uno una vd distinta
for vd_i in list_vds:
    y_train_dict[vd_i] = df_train[vd_i]
    y_test_dict[vd_i]  = df_test[vd_i]

# %%
list_vds[0]
# Out:
# 'vd_1d'

# %%
X_train_prepnres = X_train.copy()
X_val_prep = X_test.copy()
y_train_prepnres = y_train_dict[list_vds[0]].copy()
y_val = y_test_dict[list_vds[0]].copy()

# %%
# Aquí, si tuvieramos pipeline de preprocesamiento deberíamos:
# preprocesar el X_Train, y luego resamplearlo (tanto a X_train como a y_train)
# y al x_validacion solo preprocesarlo

# %% [markdown]
# # Modelado

# %% [markdown]
# ## Definimos el clasificador a utilizar

# %%
if CLASIFICADOR == 'LGBM':
    clf = lgb.LGBMClassifier()
elif CLASIFICADOR == 'RANDOM_FOREST':
    clf = RandomForestClassifier()

# %% [markdown]
# ## Definimos hiperparámetros fijos

# %%
# Fixed params 
if CLASIFICADOR == 'LGBM':
    FIXED_PARAMS = {
                        'objective':'binary', # binary = logloss
                        'boosting_type':'gbdt', # gbdt, goss
                        'n_estimators':1000,  # acá le ponemos muchos, total después se aplicará early_stopping, lo que limitará los árboles utilizados
                        'random_state': SEMILLA, 
                        'n_jobs': 1            
                     }
elif CLASIFICADOR == 'RANDOM_FOREST':
    FIXED_PARAMS = {
                     'criterion':'entropy', # suele ser mejor que 'gini'
                     'bootstrap':1, # indica que no se usará toda la muestra al armar los árboles (le fijaremos luego cantidad máxima de columnas y de registros para cada árbol)
                     'random_state': SEMILLA,
                     'n_jobs':1
                    }

# %% [markdown]
# ## Hiperparámetros y su espacio de búsqueda

# %%
# Search Space
if CLASIFICADOR == 'LGBM':
    space= [ 
            Integer(1, 10, name='max_depth') # máxima profundidad de cada árbol (en LGBM la gracia es que sean poco profundos, porque se van concatenando muchos)
            ,Integer(2, 100, name='num_leaves') # máxima cantidad de hojas
            ,Integer(100, 1000, name='min_data_in_leaf') # mínima cantidad de registros en cada hoja
            ,Real(10**-5, 10**0, "log-uniform", name = 'learning_rate') # define la tasa de aprendizaje de árbol a árbol
            ,Real(0.1, 0.7, name='colsample_bytree') # porcentaje de columnas que puede usar cada árbol
            ,Real(0.3, 0.9, name='subsample') # porcentaje de filas que puede usar cada árbol
            ,Real(1e-9, 1000, 'log-uniform', name='reg_lambda') # Regularización 1: reduce complejidad del modelo, quitando importancia a hojas menos explicativas, y penaliza llevando valores pequeños a 0
            ,Real(1e-9, 1, 'log-uniform', name='reg_alpha') # Regularización 2: reduce complejidad del modelo, quitando importancia a hojas menos explicativas, y penaliza quitando importancia a valores grandes (outliers)
        
            ]
    # listamos los nombres de los parámetros cuyo espacio de búsqueda acabamos de definir
    param_names = ['max_depth', 'num_leaves', 'min_data_in_leaf', 'learning_rate', 'colsample_bytree','subsample','reg_lambda','reg_alpha']
elif CLASIFICADOR == 'RANDOM_FOREST':
    n_cols = data.shape[1]
    space = [
                Integer(100, 300, name='n_estimators') # cantidad de árboles a utilizar
               ,Integer(5, 80, name='max_depth') # maxima profundidad de cada árbol (aquí sí es mejor que sean profundos, porque no se concatenan, son independientes)
               ,Integer(2, 20, name='min_samples_split') # mínima cantidad de registros para abrir una rama
               ,Integer(10, 100, name='min_samples_leaf') # mínima cantidad de registros para abrir una hoja
               ,Real(0.01, 0.90, name='max_samples') # máxima cantidad de registros (filas) que puede usar cada árbol
               ,Integer(round(n_cols*0.01), round(n_cols*0.5), name='max_features') # máxima cantidad de atributos (columnas) que puede usar cada árbol
               ,Real(0.0001, 0.05, name='min_impurity_decrease') # para seguir abriendo ramas se exige ganar cierto nivel de 'pureza' (sirve para que no overfitee)
            ]
    param_names=['n_estimators','max_depth','min_samples_split','min_samples_leaf','max_samples','max_features','min_impurity_decrease']

# %% [markdown]
# ## Métricas a calcular en cada iteración, definidas como función

# %%
# Primero hacemos una funcion para calcular el ks (solo para utilizar un nombre más amigable)
def ks_score(y_true, y_pred):
    """
    Returns: KS statistic
    Params:
        y_true: array of shape (n,) with true values
        y_pred: array of shape (n,) with predicted proba    
    """
    return stats.ks_2samp(y_pred[y_true==1], y_pred[y_true!=1]).statistic

# Ahora sí, definimos las métricas de evaluacion que luego utilizará nuestra búsqueda de hiperparámetros
def eval_metrics(y_true, y_pred):
    # KS
    ks = ks_score(y_true, y_pred)
    # AUC
    auc = roc_auc_score(y_true, y_pred)
    return [('ks',ks, True), ('auc',auc, True)]

# %% [markdown]
# ## Métrica que elegimos a optimizar

# %%
LOSS_METRIC = "ks"
# LOSS_METRIC = 'auc'

# %% [markdown]
# ## Función objetivo

# %%
# creamos una lista para guardar los resultados
results = []

# %%
if CLASIFICADOR == 'LGBM':
    @use_named_args(space)
    def objective(**params):
        """HP Search objective function """
        # set params
        clf.set_params(**FIXED_PARAMS)
        clf.set_params(**params)
        # train
        clf_fitted = clf.fit(
            
                    X_train_prepnres, y_train_prepnres
                    ,eval_set=[(X_val_prep, y_val),(X_train_prepnres, y_train_prepnres)]
                    ,eval_metric = eval_metrics
                    ,early_stopping_rounds = 50 # o bien se podría 0.1 * n_estimators
                    ,verbose=100)
        # get training results
        results_dict = clf_fitted.get_params()
        results_dict['n_estimators'] = clf_fitted.best_iteration_
        scores_train = {f"{k}_train": v for k, v in clf_fitted.best_score_['training'].items()}
        scores_val = {f"{k}_val": v for k, v in clf_fitted.best_score_['valid_0'].items()}
        results_dict.update(scores_train)
        results_dict.update(scores_val)
        # agrega resultados a la lista 
        results.append(results_dict)
        # minus validation score
        loss = -clf_fitted.best_score_['valid_0'][LOSS_METRIC]
        return loss
elif CLASIFICADOR == 'RANDOM_FOREST':
    @use_named_args(space)
    def objective(**params):
        """HP Search objective function"""
        # set params
        clf.set_params(**FIXED_PARAMS)
        clf.set_params(**params)
        # Nos aseguramos de que el clasificador esté fitteado con los datos preproceseados y resampleados
        clf_fitted = clf.fit(X_train_prepnres , y_train_prepnres)
        # Predecimos la Y_Val (a partir de X_val)
        y_pred = pd.DataFrame(clf_fitted.predict_proba(X_val_prep))[1] # probabilidad de ser vd = 1 
        # También predecimos la Y_train, con la que trabajamos, para tenerla de referencia
        y_pred_self = pd.DataFrame(clf_fitted.predict_proba(X_train_prepnres))[1]
        eval_metric = ks_score(pd.DataFrame(y_val).values, pd.DataFrame(y_pred).values)
        # hacemos negativo nuestro objetivo (queremos maximizar el objetivo, pero como el algoritmo minimiza, minimizamos el "menos objetivo")
        loss = -eval_metric
        # obtenemos los resultados de training
        results_dict = clf_fitted.get_params()
        scores_val={f"{k}_val": v for k, v in eval_metrics(pd.DataFrame(y_val).values, pd.DataFrame(y_pred).values).items()}
        scores_train = {f"{k}_train": v for k, v in eval_metrics(pd.DataFrame(y_Train_prepnres).values , pd.DataFrame(y_pred_self).values).items()}
        results_dict.update(scores_train)
        results_dict.update(scores_val)
        # agregamos los resultados a la lista de resultados
        results.append(results_dict)
        return loss

# %% [markdown]
# ## Ejecutamos la búsqueda Gaussiana

# %% [markdown]
# Aquí podemos utilizar `forest_minimize()` o `gp_minimize`

# %%
from tqdm.notebook import tqdm
class tqdm_skopt(object):
    def __init__(self, **kwargs):
        self._bar = tqdm(**kwargs)
        
    def __call__(self, res):
        self._bar.update()
        
# Cantidad de iteraciones para la búsqueda (utilizar muchas, aqui usamos 50 solo por probar)
n_calls = N_ITERACIONES

# Búsqueda
res = gp_minimize(
                    objective
                    ,space
                    ,n_calls = n_calls
                    ,n_initial_points = int(round(n_calls*0.2)) # Cantidad de iteraciones iniciales random (20% es significativo, pero dando mucho espacio para que el algoritmo optimice)
                    ,n_jobs=1
                    ,random_state = SEMILLA
                    ,verbose=1
                    ,callback=[tqdm_skopt(total=n_calls, desc="Gaussian Process")]
                    )
# Out:
# Gaussian Process:   0%|          | 0/50 [00:00<?, ?it/s]
# Iteration No: 1 started. Evaluating function at random point.
# [LightGBM] [Warning] min_data_in_leaf is set=761, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=761
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.65359	training's ks: 0.0575529	training's auc: 0.528776	valid_0's binary_logloss: 0.661848	valid_0's ks: 0.0992908	valid_0's auc: 0.549645
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 1.1672
# Function value obtained: -0.0993
# Current minimum: -0.0993
# Iteration No: 2 started. Evaluating function at random point.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [4]	training's binary_logloss: 0.652698	training's ks: 0.167186	training's auc: 0.611334	valid_0's binary_logloss: 0.661514	valid_0's ks: 0.100709	valid_0's auc: 0.561415
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 1.1535
# Function value obtained: -0.1007
# Current minimum: -0.1007
# Iteration No: 3 started. Evaluating function at random point.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [40]	training's binary_logloss: 0.653633	training's ks: 0.0983616	training's auc: 0.565272	valid_0's binary_logloss: 0.661977	valid_0's ks: 0.0929078	valid_0's auc: 0.543711
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 1.6971
# Function value obtained: -0.0929
# Current minimum: -0.1007
# Iteration No: 4 started. Evaluating function at random point.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	training's binary_logloss: 0.653688	training's ks: 0.108975	training's auc: 0.570879	valid_0's binary_logloss: 0.662018	valid_0's ks: 0.107801	valid_0's auc: 0.55186
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 1.0230
# Function value obtained: -0.1078
# Current minimum: -0.1078
# Iteration No: 5 started. Evaluating function at random point.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [13]	training's binary_logloss: 0.653684	training's ks: 0.164293	training's auc: 0.61033	valid_0's binary_logloss: 0.662017	valid_0's ks: 0.0879433	valid_0's auc: 0.542893
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 1.1524
# Function value obtained: -0.0879
# Current minimum: -0.1078
# Iteration No: 6 started. Evaluating function at random point.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [18]	training's binary_logloss: 0.653666	training's ks: 0.0985698	training's auc: 0.551343	valid_0's binary_logloss: 0.662015	valid_0's ks: 0.0751773	valid_0's auc: 0.518319
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 1.3853
# Function value obtained: -0.0752
# Current minimum: -0.1078
# Iteration No: 7 started. Evaluating function at random point.
# Training until validation scores don't improve for 50 rounds
# [100]	training's binary_logloss: 0.643641	training's ks: 0.209855	training's auc: 0.629042	valid_0's binary_logloss: 0.655193	valid_0's ks: 0.164539	valid_0's auc: 0.587709
# Early stopping, best iteration is:
# [69]	training's binary_logloss: 0.646087	training's ks: 0.195832	training's auc: 0.616967	valid_0's binary_logloss: 0.65601	valid_0's ks: 0.156028	valid_0's auc: 0.589611
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 2.5393
# Function value obtained: -0.1560
# Current minimum: -0.1560
# Iteration No: 8 started. Evaluating function at random point.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [13]	training's binary_logloss: 0.65352	training's ks: 0.21461	training's auc: 0.636479	valid_0's binary_logloss: 0.661922	valid_0's ks: 0.153901	valid_0's auc: 0.586483
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 1.4099
# Function value obtained: -0.1539
# Current minimum: -0.1560
# Iteration No: 9 started. Evaluating function at random point.
# Training until validation scores don't improve for 50 rounds
# [100]	training's binary_logloss: 0.652171	training's ks: 0.131677	training's auc: 0.576734	valid_0's binary_logloss: 0.660966	valid_0's ks: 0.125532	valid_0's auc: 0.551151
# Early stopping, best iteration is:
# [65]	training's binary_logloss: 0.652669	training's ks: 0.118764	training's auc: 0.572596	valid_0's binary_logloss: 0.661271	valid_0's ks: 0.143972	valid_0's auc: 0.548344
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 2.5008
# Function value obtained: -0.1440
# Current minimum: -0.1560
# Iteration No: 10 started. Evaluating function at random point.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [11]	training's binary_logloss: 0.653688	training's ks: 0.0826343	training's auc: 0.559357	valid_0's binary_logloss: 0.662018	valid_0's ks: 0.146809	valid_0's auc: 0.566139
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 2.0369
# Function value obtained: -0.1468
# Current minimum: -0.1560
# Iteration No: 11 started. Searching for the next optimal point.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [23]	training's binary_logloss: 0.631745	training's ks: 0.223439	training's auc: 0.637721	valid_0's binary_logloss: 0.654555	valid_0's ks: 0.135461	valid_0's auc: 0.575113
# Iteration No: 11 ended. Search finished for the next optimal point.
# Time taken: 2.2979
# Function value obtained: -0.1355
# Current minimum: -0.1560
# Iteration No: 12 started. Searching for the next optimal point.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	training's binary_logloss: 0.653689	training's ks: 0.0772084	training's auc: 0.555865	valid_0's binary_logloss: 0.662018	valid_0's ks: 0.0673759	valid_0's auc: 0.540082
# Iteration No: 12 ended. Search finished for the next optimal point.
# Time taken: 1.5823
# Function value obtained: -0.0674
# Current minimum: -0.1560
# Iteration No: 13 started. Searching for the next optimal point.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [4]	training's binary_logloss: 0.653012	training's ks: 0.226621	training's auc: 0.648861	valid_0's binary_logloss: 0.661798	valid_0's ks: 0.139007	valid_0's auc: 0.585853
# Iteration No: 13 ended. Search finished for the next optimal point.
# Time taken: 1.6558
# Function value obtained: -0.1390
# Current minimum: -0.1560
# Iteration No: 14 started. Searching for the next optimal point.
# Training until validation scores don't improve for 50 rounds
# [100]	training's binary_logloss: 0.649431	training's ks: 0.162747	training's auc: 0.602398	valid_0's binary_logloss: 0.656779	valid_0's ks: 0.165957	valid_0's auc: 0.594221
# Early stopping, best iteration is:
# [116]	training's binary_logloss: 0.648903	training's ks: 0.172715	training's auc: 0.605676	valid_0's binary_logloss: 0.656328	valid_0's ks: 0.18156	valid_0's auc: 0.59447
# Iteration No: 14 ended. Search finished for the next optimal point.
# Time taken: 3.8652
# Function value obtained: -0.1816
# Current minimum: -0.1816
# Iteration No: 15 started. Searching for the next optimal point.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [8]	training's binary_logloss: 0.653688	training's ks: 0.199139	training's auc: 0.627546	valid_0's binary_logloss: 0.662018	valid_0's ks: 0.109929	valid_0's auc: 0.561283
# Iteration No: 15 ended. Search finished for the next optimal point.
# Time taken: 1.8089
# Function value obtained: -0.1099
# Current minimum: -0.1816
# Iteration No: 16 started. Searching for the next optimal point.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [7]	training's binary_logloss: 0.641837	training's ks: 0.2565	training's auc: 0.669005	valid_0's binary_logloss: 0.657117	valid_0's ks: 0.16383	valid_0's auc: 0.57912
# Iteration No: 16 ended. Search finished for the next optimal point.
# Time taken: 2.0634
# Function value obtained: -0.1638
# Current minimum: -0.1816
# Iteration No: 17 started. Searching for the next optimal point.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [31]	training's binary_logloss: 0.651453	training's ks: 0.142293	training's auc: 0.589813	valid_0's binary_logloss: 0.659268	valid_0's ks: 0.144681	valid_0's auc: 0.575898
# Iteration No: 17 ended. Search finished for the next optimal point.
# Time taken: 2.3071
# Function value obtained: -0.1447
# Current minimum: -0.1816
# Iteration No: 18 started. Searching for the next optimal point.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.653688	training's ks: 0.0660096	training's auc: 0.533005	valid_0's binary_logloss: 0.662018	valid_0's ks: 0.120567	valid_0's auc: 0.560284
# Iteration No: 18 ended. Search finished for the next optimal point.
# Time taken: 1.4446
# Function value obtained: -0.1206
# Current minimum: -0.1816
# Iteration No: 19 started. Searching for the next optimal point.
# Training until validation scores don't improve for 50 rounds
# [100]	training's binary_logloss: 0.645028	training's ks: 0.185065	training's auc: 0.617711	valid_0's binary_logloss: 0.654683	valid_0's ks: 0.166667	valid_0's auc: 0.597476
# Early stopping, best iteration is:
# [67]	training's binary_logloss: 0.647281	training's ks: 0.177599	training's auc: 0.61216	valid_0's binary_logloss: 0.655877	valid_0's ks: 0.184397	valid_0's auc: 0.601037
# Iteration No: 19 ended. Search finished for the next optimal point.
# Time taken: 3.1957
# Function value obtained: -0.1844
# Current minimum: -0.1844
# Iteration No: 20 started. Searching for the next optimal point.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.68922	training's ks: 0	training's auc: 0.5	valid_0's binary_logloss: 0.70588	valid_0's ks: 0	valid_0's auc: 0.5
# Iteration No: 20 ended. Search finished for the next optimal point.
# Time taken: 0.7040
# Function value obtained: -0.0000
# Current minimum: -0.1844
# Iteration No: 21 started. Searching for the next optimal point.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [31]	training's binary_logloss: 0.64197	training's ks: 0.207092	training's auc: 0.630441	valid_0's binary_logloss: 0.65287	valid_0's ks: 0.176596	valid_0's auc: 0.601958
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 2.1460
# Function value obtained: -0.1766
# Current minimum: -0.1844
# Iteration No: 22 started. Searching for the next optimal point.
# Training until validation scores don't improve for 50 rounds
# [100]	training's binary_logloss: 0.63342	training's ks: 0.209107	training's auc: 0.640565	valid_0's binary_logloss: 0.656359	valid_0's ks: 0.119858	valid_0's auc: 0.562619
# Early stopping, best iteration is:
# [85]	training's binary_logloss: 0.635194	training's ks: 0.209239	training's auc: 0.636409	valid_0's binary_logloss: 0.656165	valid_0's ks: 0.139007	valid_0's auc: 0.564045
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 3.7161
# Function value obtained: -0.1390
# Current minimum: -0.1844
# Iteration No: 23 started. Searching for the next optimal point.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	training's binary_logloss: 0.645233	training's ks: 0.118089	training's auc: 0.573777	valid_0's binary_logloss: 0.656212	valid_0's ks: 0.11773	valid_0's auc: 0.570198
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 2.0411
# Function value obtained: -0.1177
# Current minimum: -0.1844
# Iteration No: 24 started. Searching for the next optimal point.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [11]	training's binary_logloss: 0.647939	training's ks: 0.171918	training's auc: 0.598983	valid_0's binary_logloss: 0.656649	valid_0's ks: 0.196454	valid_0's auc: 0.595303
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 1.9729
# Function value obtained: -0.1965
# Current minimum: -0.1965
# Iteration No: 25 started. Searching for the next optimal point.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.650988	training's ks: 0.0567113	training's auc: 0.528356	valid_0's binary_logloss: 0.6545	valid_0's ks: 0.114894	valid_0's auc: 0.557447
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 1.6821
# Function value obtained: -0.1149
# Current minimum: -0.1965
# Iteration No: 26 started. Searching for the next optimal point.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [42]	training's binary_logloss: 0.633833	training's ks: 0.216677	training's auc: 0.644468	valid_0's binary_logloss: 0.655959	valid_0's ks: 0.112766	valid_0's auc: 0.566663
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 2.5599
# Function value obtained: -0.1128
# Current minimum: -0.1965
# Iteration No: 27 started. Searching for the next optimal point.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [29]	training's binary_logloss: 0.642448	training's ks: 0.192681	training's auc: 0.621942	valid_0's binary_logloss: 0.652355	valid_0's ks: 0.170213	valid_0's auc: 0.600415
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 2.3095
# Function value obtained: -0.1702
# Current minimum: -0.1965
# Iteration No: 28 started. Searching for the next optimal point.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [6]	training's binary_logloss: 0.653689	training's ks: 0.08718	training's auc: 0.555721	valid_0's binary_logloss: 0.662018	valid_0's ks: 0.126241	valid_0's auc: 0.556428
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 1.7774
# Function value obtained: -0.1262
# Current minimum: -0.1965
# Iteration No: 29 started. Searching for the next optimal point.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [49]	training's binary_logloss: 0.647182	training's ks: 0.177084	training's auc: 0.612745	valid_0's binary_logloss: 0.655962	valid_0's ks: 0.187943	valid_0's auc: 0.598819
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 2.8516
# Function value obtained: -0.1879
# Current minimum: -0.1965
# Iteration No: 30 started. Searching for the next optimal point.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [8]	training's binary_logloss: 0.639688	training's ks: 0.170883	training's auc: 0.602372	valid_0's binary_logloss: 0.655714	valid_0's ks: 0.128369	valid_0's auc: 0.569089
# Iteration No: 30 ended. Search finished for the next optimal point.
# Time taken: 1.9744
# Function value obtained: -0.1284
# Current minimum: -0.1965
# Iteration No: 31 started. Searching for the next optimal point.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [6]	training's binary_logloss: 0.653689	training's ks: 0.0806725	training's auc: 0.555216	valid_0's binary_logloss: 0.662018	valid_0's ks: 0.126241	valid_0's auc: 0.557243
# Iteration No: 31 ended. Search finished for the next optimal point.
# Time taken: 1.8840
# Function value obtained: -0.1262
# Current minimum: -0.1965
# Iteration No: 32 started. Searching for the next optimal point.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [10]	training's binary_logloss: 0.642561	training's ks: 0.150245	training's auc: 0.596453	valid_0's binary_logloss: 0.654765	valid_0's ks: 0.141135	valid_0's auc: 0.576852
# Iteration No: 32 ended. Search finished for the next optimal point.
# Time taken: 2.0285
# Function value obtained: -0.1411
# Current minimum: -0.1965
# Iteration No: 33 started. Searching for the next optimal point.
# Training until validation scores don't improve for 50 rounds
# [100]	training's binary_logloss: 0.644313	training's ks: 0.188757	training's auc: 0.620204	valid_0's binary_logloss: 0.654074	valid_0's ks: 0.17234	valid_0's auc: 0.598608
# Early stopping, best iteration is:
# [62]	training's binary_logloss: 0.647116	training's ks: 0.181242	training's auc: 0.612932	valid_0's binary_logloss: 0.655734	valid_0's ks: 0.190071	valid_0's auc: 0.601324
# Iteration No: 33 ended. Search finished for the next optimal point.
# Time taken: 3.2858
# Function value obtained: -0.1901
# Current minimum: -0.1965
# Iteration No: 34 started. Searching for the next optimal point.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.68922	training's ks: 0	training's auc: 0.5	valid_0's binary_logloss: 0.70588	valid_0's ks: 0	valid_0's auc: 0.5
# Iteration No: 34 ended. Search finished for the next optimal point.
# Time taken: 1.1816
# Function value obtained: -0.0000
# Current minimum: -0.1965
# Iteration No: 35 started. Searching for the next optimal point.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [11]	training's binary_logloss: 0.647939	training's ks: 0.171918	training's auc: 0.598983	valid_0's binary_logloss: 0.656649	valid_0's ks: 0.196454	valid_0's auc: 0.595303
# Iteration No: 35 ended. Search finished for the next optimal point.
# Time taken: 2.2350
# Function value obtained: -0.1965
# Current minimum: -0.1965
# Iteration No: 36 started. Searching for the next optimal point.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [36]	training's binary_logloss: 0.643397	training's ks: 0.170004	training's auc: 0.61544	valid_0's binary_logloss: 0.657037	valid_0's ks: 0.121277	valid_0's auc: 0.565003
# Iteration No: 36 ended. Search finished for the next optimal point.
# Time taken: 3.2650
# Function value obtained: -0.1213
# Current minimum: -0.1965
# Iteration No: 37 started. Searching for the next optimal point.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [9]	training's binary_logloss: 0.642906	training's ks: 0.152034	training's auc: 0.592998	valid_0's binary_logloss: 0.65403	valid_0's ks: 0.108511	valid_0's auc: 0.56867
# Iteration No: 37 ended. Search finished for the next optimal point.
# Time taken: 2.4803
# Function value obtained: -0.1085
# Current minimum: -0.1965
# Iteration No: 38 started. Searching for the next optimal point.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [11]	training's binary_logloss: 0.647939	training's ks: 0.171918	training's auc: 0.598983	valid_0's binary_logloss: 0.656649	valid_0's ks: 0.196454	valid_0's auc: 0.595303
# Iteration No: 38 ended. Search finished for the next optimal point.
# Time taken: 2.2297
# Function value obtained: -0.1965
# Current minimum: -0.1965
# Iteration No: 39 started. Searching for the next optimal point.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [11]	training's binary_logloss: 0.647939	training's ks: 0.171918	training's auc: 0.598983	valid_0's binary_logloss: 0.656649	valid_0's ks: 0.196454	valid_0's auc: 0.595303
# Iteration No: 39 ended. Search finished for the next optimal point.
# Time taken: 2.1751
# Function value obtained: -0.1965
# Current minimum: -0.1965
# Iteration No: 40 started. Searching for the next optimal point.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [11]	training's binary_logloss: 0.647939	training's ks: 0.171918	training's auc: 0.598983	valid_0's binary_logloss: 0.656649	valid_0's ks: 0.196454	valid_0's auc: 0.595303
# Iteration No: 40 ended. Search finished for the next optimal point.
# Time taken: 2.9629
# Function value obtained: -0.1965
# Current minimum: -0.1965
# Iteration No: 41 started. Searching for the next optimal point.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [18]	training's binary_logloss: 0.646892	training's ks: 0.142036	training's auc: 0.593961	valid_0's binary_logloss: 0.658186	valid_0's ks: 0.114894	valid_0's auc: 0.557228
# Iteration No: 41 ended. Search finished for the next optimal point.
# Time taken: 2.7158
# Function value obtained: -0.1149
# Current minimum: -0.1965
# Iteration No: 42 started. Searching for the next optimal point.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [4]	training's binary_logloss: 0.635198	training's ks: 0.187951	training's auc: 0.61886	valid_0's binary_logloss: 0.649737	valid_0's ks: 0.11844	valid_0's auc: 0.585159
# Iteration No: 42 ended. Search finished for the next optimal point.
# Time taken: 2.5015
# Function value obtained: -0.1184
# Current minimum: -0.1965
# Iteration No: 43 started. Searching for the next optimal point.
# Training until validation scores don't improve for 50 rounds
# [100]	training's binary_logloss: 0.651864	training's ks: 0.139118	training's auc: 0.578818	valid_0's binary_logloss: 0.659909	valid_0's ks: 0.158865	valid_0's auc: 0.576136
# Early stopping, best iteration is:
# [102]	training's binary_logloss: 0.651833	training's ks: 0.139118	training's auc: 0.578972	valid_0's binary_logloss: 0.659867	valid_0's ks: 0.163121	valid_0's auc: 0.576822
# Iteration No: 43 ended. Search finished for the next optimal point.
# Time taken: 4.5112
# Function value obtained: -0.1631
# Current minimum: -0.1965
# Iteration No: 44 started. Searching for the next optimal point.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [11]	training's binary_logloss: 0.647939	training's ks: 0.171918	training's auc: 0.598983	valid_0's binary_logloss: 0.656649	valid_0's ks: 0.196454	valid_0's auc: 0.595303
# Iteration No: 44 ended. Search finished for the next optimal point.
# Time taken: 2.2511
# Function value obtained: -0.1965
# Current minimum: -0.1965
# Iteration No: 45 started. Searching for the next optimal point.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [11]	training's binary_logloss: 0.648126	training's ks: 0.170237	training's auc: 0.598853	valid_0's binary_logloss: 0.65681	valid_0's ks: 0.196454	valid_0's auc: 0.594405
# Iteration No: 45 ended. Search finished for the next optimal point.
# Time taken: 2.2435
# Function value obtained: -0.1965
# Current minimum: -0.1965
# Iteration No: 46 started. Searching for the next optimal point.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.621515	training's ks: 0.221582	training's auc: 0.648771	valid_0's binary_logloss: 0.665892	valid_0's ks: 0.141844	valid_0's auc: 0.560231
# Iteration No: 46 ended. Search finished for the next optimal point.
# Time taken: 2.4623
# Function value obtained: -0.1418
# Current minimum: -0.1965
# Iteration No: 47 started. Searching for the next optimal point.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	training's binary_logloss: 0.645831	training's ks: 0.241752	training's auc: 0.658286	valid_0's binary_logloss: 0.65859	valid_0's ks: 0.157447	valid_0's auc: 0.583756
# Iteration No: 47 ended. Search finished for the next optimal point.
# Time taken: 2.3447
# Function value obtained: -0.1574
# Current minimum: -0.1965
# Iteration No: 48 started. Searching for the next optimal point.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [29]	training's binary_logloss: 0.642448	training's ks: 0.192681	training's auc: 0.621942	valid_0's binary_logloss: 0.652355	valid_0's ks: 0.170213	valid_0's auc: 0.600415
# Iteration No: 48 ended. Search finished for the next optimal point.
# Time taken: 2.7345
# Function value obtained: -0.1702
# Current minimum: -0.1965
# Iteration No: 49 started. Searching for the next optimal point.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [10]	training's binary_logloss: 0.633462	training's ks: 0.188909	training's auc: 0.62384	valid_0's binary_logloss: 0.654974	valid_0's ks: 0.101418	valid_0's auc: 0.566237
# Iteration No: 49 ended. Search finished for the next optimal point.
# Time taken: 2.5770
# Function value obtained: -0.1014
# Current minimum: -0.1965
# Iteration No: 50 started. Searching for the next optimal point.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [11]	training's binary_logloss: 0.647939	training's ks: 0.171918	training's auc: 0.598983	valid_0's binary_logloss: 0.656649	valid_0's ks: 0.196454	valid_0's auc: 0.595303
# Iteration No: 50 ended. Search finished for the next optimal point.
# Time taken: 2.5745
# Function value obtained: -0.1965
# Current minimum: -0.1965

# %% [markdown]
# # Resultados

# %%
df_results = pd.DataFrame.from_dict(results)
if CLASIFICADOR == 'LGBM':
    params_to_watch = ['n_estimators'] + param_names
elif CLASIFICADOR == 'RANDOM_FOREST':
    params_to_watch = param_names
cols_order = params_to_watch + ['ks_train','ks_val','auc_train','auc_val']
df_results = df_results[cols_order]
df_results.sort_values(by='ks_val',ascending=False, inplace=True)
df_results = df_results.reset_index().rename(columns={'index':'n_iter'})
df_results
# Out:
#     n_iter  n_estimators  max_depth  num_leaves  min_data_in_leaf  \
# 0       49            11          1          52               100
# 1       43            11          1         100               100
# 2       34            11          1           2               100
# 3       39            11          4           2               100
# 4       23            11          1          37               207
# 5       37            11          1           2               156
# 6       38            11          8           2               100
# 7       44            11          1         100               100
# 8       32            62          1          94               208
# 9       28            49          1          27               269
# 10      18            67          1          46               157
# 11      13           116          1          76               197
# 12      20            31          1          74               281
# 13      47            29         10           2               100
# 14      26            29          1          56               210
# 15      15             7          7          58               220
# 16      42           102          1           2               186
# 17      46             3         10         100               100
# 18       6            69          2          81               146
# 19       7            13          3          41               257
# 20       9            11          9          72               735
# 21      16            31          1          94               230
# 22       8            65          8          70               653
# 23      45             1          8          55               120
# 24      31            10          1          90               508
# 25      21            85          1          77               534
# 26      12             4          4          67               100
# 27      10            23          1          86               448
# 28      29             8         10          23               600
# 29      27             6         10          83               719
# 30      30             6          1          93               717
# 31      35            36          1           2               500
# 32      17             1          1          73               194
# 33      41             4          2          78               357
# 34      22             3          1           4               100
# 35      40            18         10           2               661
# 36      24             1          1          29               310
# 37      25            42         10          45               548
# 38      14             8          4          89               188
# 39      36             9         10          16               727
# 40       3             3          9          42               626
# 41      48            10         10         100               627
# 42       1             4          9          39               347
# 43       0             1          8          84               761
# 44       2            40          4          63               724
# 45       4            13          2          81               403
# 46       5            18          4          21               946
# 47      11             3          5          80               847
# 48      33             1         10          80              1000
# 49      19             1          1          95              1000
#
#     learning_rate  colsample_bytree   subsample     reg_lambda   reg_alpha  \
# 0     1.000000000       0.700000000 0.300000000 1000.000000000 0.000000001
# 1     1.000000000       0.700000000 0.900000000 1000.000000000 0.000000001
# 2     1.000000000       0.700000000 0.300000000 1000.000000000 0.000000001
# 3     1.000000000       0.700000000 0.900000000 1000.000000000 0.000000001
# 4     1.000000000       0.700000000 0.614627195 1000.000000000 0.000000001
# Out:
# Los mejores hiperparámetros son:
# {'max_depth': 1.0,
#  'num_leaves': 52.0,
#  'min_data_in_leaf': 100.0,
#  'learning_rate': 1.0,
#  'colsample_bytree': 0.7,
#  'subsample': 0.3,
#  'reg_lambda': 1000.0,
#  'reg_alpha': 1e-09,
#  'objective': 'binary',
#  'boosting_type': 'gbdt',
#  'n_estimators': 1000,
#  'random_state': 99,
#  'n_jobs': 1}
# y alcanzan un KS de 0.19645390070921986

# %% [markdown]
# Corregiremos el tipo de dato hay hiperparámetros que deben ser **int** pero se guardan como **float**

# %%
if CLASIFICADOR == 'LGBM':
    # convertimos a int
    best_param['n_estimators'] = int(best_param['n_estimators'])
    best_param['max_depth'] = int(best_param['max_depth'])
    best_param['num_leaves'] = int(best_param['num_leaves'])
    best_param['min_data_in_leaf'] = int(best_param['min_data_in_leaf'])
elif CLASIFICADOR == 'RANDOM_FOREST':
    best_param['n_estimators'] = int(best_param['n_estimators'])
    best_param['max_depth'] = int(best_param['max_depth'])
    best_param['min_samples_split'] = int(best_param['min_samples_split'])
    best_param['min_samples_leaf'] = int(best_param['min_samples_leaf'])
    best_param['max_features'] = int(best_param['max_features'])
    best_param['random_state'] = int(best_param['random_state'])
    best_param['bootstrap'] = int(best_param['bootstrap'])

# %% [markdown]
# # Creamos en limpio el clasificador

# %%
# Init Model 
if CLASIFICADOR == 'LGBM':
    clf = lgb.LGBMClassifier()
    clf.set_params(**best_param)
    # Fit to data
    clf_fitted = clf.fit(
                            X_train_prepnres, y_train_prepnres
                            ,eval_set = [(X_val_prep, y_val), (X_train_prepnres, y_train_prepnres)]
                            ,eval_metric=eval_metrics
                            ,early_stopping_rounds=50 # o 0.1 * n_estimators
                            ,verbose=100 
                        )
elif CLASIFICADOR=='RANDOM_FOREST':
    clf=RandomForestClassifier()
    clf.set_params(**best_param)
    # Fit to data
    clf_fitted = clf.fit(X_Train_prepnres, y_train_prepnres)
# Out:
# LGBMClassifier(colsample_bytree=0.7, learning_rate=1.0, max_depth=1,
#                min_data_in_leaf=100, n_estimators=1000, n_jobs=1, num_leaves=52,
#                objective='binary', random_state=99, reg_alpha=1e-09,
#                reg_lambda=1000.0, subsample=0.3)
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [11]	training's binary_logloss: 0.647939	training's ks: 0.171918	training's auc: 0.598983	valid_0's binary_logloss: 0.656649	valid_0's ks: 0.196454	valid_0's auc: 0.595303

# %% [markdown]
# ## Agregamos el clasificador como último step del pipeline

# %%
#### Hacerlo cuando haya pipeline!

# %% [markdown]
# # Exportación

# %%
# Guardamos los mejores hiperparámetros
joblib.dump(best_param, MODELOS/f"HPS_bparams_ggal_{CLASIFICADOR}.joblib")
# Tambien guardamos el clasificador
joblib.dump(clf_fitted, MODELOS/f"HPS_clf_fitted_ggal_{CLASIFICADOR}.joblib")
# Out:
# ['..\\modelos\\HPS_bparams_ggal_LGBM.joblib']
# ['..\\modelos\\HPS_clf_fitted_ggal_LGBM.joblib']

# %%
# Tomo el tiempo al final de la ejecucion
end_time=time.time()
print('El script demora', (end_time-start_time)/60, 'minutos')
# Out:
# El script demora 1.8824271043141683 minutos
